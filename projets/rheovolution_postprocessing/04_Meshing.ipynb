# %%
# !python --version
# Out:
# Python 3.10.9

# %%
import matplotlib.pyplot as plt
import numpy             as np
import os

# %% [markdown]
# # Data structure and algorithms for meshing from ADELI's p-file data
